# %%
import torch

# %%
tensor_id = torch.tensor([1,2,3,4,5])

# %%
print(tensor_id)
# Out:
# tensor([1, 2, 3, 4, 5])

# %%
type(tensor_id)
# Out:
# torch.Tensor

# %%
tensor_a=torch.tensor([1,2,3,5])
tensor_b=torch.tensor([2,3,4,5])

# %%
result_addition = tensor_a + tensor_b
result_addition
# Out:
# tensor([ 3,  5,  7, 10])

# %%
result_subtraction = tensor_a-tensor_b
result_subtraction
# Out:
# tensor([-1, -1, -1,  0])

# %%
result_multiplication = tensor_a*tensor_b
result_multiplication
# Out:
# tensor([ 2,  6, 12, 25])

# %%
matrix_a = torch.tensor([[1,2],[3,4]])

# %%
matrix_b = torch.tensor([[2,3],[3,4]])
result_matrix = torch.mm(matrix_a, matrix_b)
result_matrix
# Out:
# tensor([[ 8, 11],
#         [18, 25]])

# %%
original_tensor = torch.tensor([[1,2,3],[4,5,6]])
reshaped_tensor = original_tensor.view(6,1)
print(f"Original : {original_tensor}")
reshaped_tensor
# Out:
# Original : tensor([[1, 2, 3],
#         [4, 5, 6]])
# tensor([[1],
#         [2],
#         [3],
#         [4],
#         [5],
#         [6]])

# %%
tensor_c = torch.tensor([[1,2,3],[3,4,5]])
tensor_c[1][0]
# Out:
# tensor(3)

# %%
tensor_for_reduction = torch.tensor([[1,2,3],[4,5,6]])
torch.sum(tensor_for_reduction,dim=-1)
# Out:
# tensor([ 6, 15])

# %%
torch.cat((tensor_a,tensor_b),dim=-1)
# Out:
# tensor([1, 2, 3, 5, 2, 3, 4, 5])

# %%
a = torch.rand(2,6)

# %%
torch.sort(a)
# Out:
# torch.return_types.sort(
# values=tensor([[0.1529, 0.1586, 0.3539, 0.5659, 0.6742, 0.7353],
#         [0.0636, 0.5038, 0.6794, 0.7458, 0.7851, 0.7987]]),
# indices=tensor([[4, 2, 0, 1, 3, 5],
#         [3, 0, 4, 2, 5, 1]]))

# %%
tensor_for_grad = torch.tensor([2.0], requires_grad=True)

# %%
result = tensor_for_grad ** 2
result
# Out:
# tensor([4.], grad_fn=<PowBackward0>)

# %%
print(result.backward())
# Out:
# None

# %%
result
# Out:
# tensor([4.], grad_fn=<PowBackward0>)
