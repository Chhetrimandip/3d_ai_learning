# %%
import torch
import numpy as np

# %%
num_points = 20000

# %%
points_xyz = np.random.rand(num_points,3)

# %%
tensor_xyz = torch.from_numpy(points_xyz)

# %%
if torch.accelerator.is_available():
    print("Yes it is available it is" + torch.accelerator.current_accelerator())
else:
    print("huhu no resorce")
# Out:
# huhu no resorce
